# %% [markdown]
# # Introduction
#
# **Python for HPC course**
#
# Sebastian Ohlmann, Klaus Reuter
#
# Max Planck Computing and Data Facility, Garching

# %% [markdown]
# ## Why Python in HPC?
# * Efficiency w.r.t. development effort:
#   $\rightarrow$ Python helps you to get "things done" quickly and focus on science.
# * Efficiency w.r.t. hardware utilization:
#   $\rightarrow$ Python-based codes may perform well if implemented correctly.
# * Using Python may achieve a good overall efficiency for small- to medium-scale codes
# * And finally ... Python is already there, so we have do deal with it!

# %% [markdown]
# ## Examples for HPC Codes using Python
#
# ### [GPAW](https://wiki.fysik.dtu.dk/gpaw/)
#
# * Density-functional theory code for material science
# * Implemented as a Python module (C++ core, Python UI)
# * Parallelization: MPI + OpenMP, scales to O(10k) cores
#
# ### [ESPResSo++](http://www.espresso-pp.de)
#
# * Molecular dynamics package for soft matter simulation,
#   MPI for Polymer Research, Mainz
# * Implemented as a Python module (C++ core, Python UI)
# * Parallelization: Domain decomposition using MPI

# %% [markdown]
# ## Scope of this tutorial
# * Learn about the tools and techniques to write efficient Python code for scientific computing
# ![gain vs effort](fig/gain_vs_effort.svg)

# %% [markdown]
# ## Course Outline
#
# * Introduction
# * Refresher of Python and the Python Ecosystem
# * Scientific Computing with Python: NumPy and SciPy
# * Performance: Cython, Numba, C/Fortran interfacing
# * Parallelism: multiprocessing, mpi4py
# * Software Engineering

# %% [markdown]
# ### *Python for HPC* complements advanced HPC courses
# * We cannot cover traditional HPC topics in depth, and would highly recommend the following courses
#     * Parallel programming with MPI
#     * Parallel programming with OpenMP
#     * Advanced parallel programming with OpenMP and MPI
#     * Node-level performance engineering
# * Watch out for these courses which are regularly offered by HLRS, LRZ, RRZE

# %% [markdown]
# ## About this Python for HPC tutorial
#
# * Practical hands-on approach with code examples
# * Presentation is mainly based on Jupyter notebooks
# * Course material available for download at
#   http://mpcdf.pages.mpcdf.de/lectures/pyhpc/
# * Questions and discussions are highly appreciated

# %% [markdown]
# ## Software prerequisites
# * Python >=3.6
# * Jupyter
# * NumPy, SciPy
# * matplotlib
# * Cython
# * gcc, gfortran
# * Numba
# * optional: MPI, mpi4py

# %% [markdown]
# ### Python environment for your computer, options:
# 1. On a recent Linux installation, install all the necessary packages via the package manager
# 2. Install the Anaconda Python Distribution
#     * Python distribution for scientific computing, available at
#       https://conda.io/docs/user-guide/install/download.html
#     * also available on Macs and on Windows (both not tested by ourselves)
#     * we provide a convenient script for download and installation:
#       check and run `install_anaconda.sh` in the folder `aux`

# %% [markdown]
# ### MPCDF Python infrastructure
# * Python (2.7, **3.7**) is provided via the Anaconda Python Distribution
# * accessible via environment modules, e.g.
#     `module purge`
#     `module load gcc impi`
#     `module load anaconda/3`
#     `module load mpi4py`

# %% [markdown]
# ### JupyterHubs in the Cloud
#
# * Note: Temporary service during this course, all files will be deleted on Nov 30 2020
# * Participants from the MPG may log into
#     * https://shoemaker.mpcdf.mpg.de/
#     * https://levy.mpcdf.mpg.de/
#     * Login with guest account ($\rightarrow$ check your MPG email account)
#     * Not a HPC environment, but suitable to do the exercises
# * Course material is already present in the homedirectory
# * **Please don't forget to "close and halt" your notebooks!**

# %% [markdown]
# ### Thank you -- Questions?
